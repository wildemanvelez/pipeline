# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
names= ['maint',
'doors',
'persons',
'lug_boot',
'safety ',]

# %%
data = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/car/car.data', names=names)

# %%
data.head()
# Out:
#             maint doors persons lug_boot safety
# vhigh vhigh     2     2   small      low   unacc
#       vhigh     2     2   small      med   unacc
#       vhigh     2     2   small     high   unacc
#       vhigh     2     2     med      low   unacc
#       vhigh     2     2     med      med   unacc

# %%
x=data.iloc[:,:-1]

# %%
y=data.iloc[:,-1]

# %%
x
# Out:
#              maint doors persons lug_boot
# vhigh vhigh      2     2   small      low
#       vhigh      2     2   small      med
#       vhigh      2     2   small     high
#       vhigh      2     2     med      low
#       vhigh      2     2     med      med
#       vhigh      2     2     med     high
#       vhigh      2     2     big      low
#       vhigh      2     2     big      med
#       vhigh      2     2     big     high
#       vhigh      2     4   small      low
#       vhigh      2     4   small      med
#       vhigh      2     4   small     high
#       vhigh      2     4     med      low
#       vhigh      2     4     med      med
#       vhigh      2     4     med     high
#       vhigh      2     4     big      low
#       vhigh      2     4     big      med
#       vhigh      2     4     big     high
#       vhigh      2  more   small      low
#       vhigh      2  more   small      med
#       vhigh      2  more   small     high
#       vhigh      2  more     med      low
#       vhigh      2  more     med      med
#       vhigh      2  more     med     high
#       vhigh      2  more     big      low
#       vhigh      2  more     big      med
#       vhigh      2  more     big     high
#       vhigh      3     2   small      low
#       vhigh      3     2   small      med
#       vhigh      3     2   small     high
# ...            ...   ...     ...      ...
# low   low        4  more     big      low
#       low        4  more     big      med
#       low        4  more     big     high
#       low    5more     2   small      low
#       low    5more     2   small      med
#       low    5more     2   small     high
#       low    5more     2     med      low
#       low    5more     2     med      med
#       low    5more     2     med     high
#       low    5more     2     big      low
#       low    5more     2     big      med
#       low    5more     2     big     high
#       low    5more     4   small      low
#       low    5more     4   small      med
#       low    5more     4   small     high
#       low    5more     4     med      low
#       low    5more     4     med      med
#       low    5more     4     med     high
#       low    5more     4     big      low
#       low    5more     4     big      med
#       low    5more     4     big     high
#       low    5more  more   small      low
#       low    5more  more   small      med
#       low    5more  more   small     high
#       low    5more  more     med      low
#       low    5more  more     med      med
#       low    5more  more     med     high
#       low    5more  more     big      low
#       low    5more  more     big      med
#       low    5more  more     big     high
#
# [1728 rows x 4 columns]

# %%
x = pd.get_dummies(x)

# %%
x
# Out:
#              maint_2  maint_3  maint_4  maint_5more  doors_2  doors_4  \
# vhigh vhigh        1        0        0            0        1        0
#       vhigh        1        0        0            0        1        0
#       vhigh        1        0        0            0        1        0
#       vhigh        1        0        0            0        1        0
#       vhigh        1        0        0            0        1        0
#       vhigh        1        0        0            0        1        0
#       vhigh        1        0        0            0        1        0
#       vhigh        1        0        0            0        1        0
#       vhigh        1        0        0            0        1        0
#       vhigh        1        0        0            0        0        1
#       vhigh        1        0        0            0        0        1
#       vhigh        1        0        0            0        0        1
#       vhigh        1        0        0            0        0        1
#       vhigh        1        0        0            0        0        1
#       vhigh        1        0        0            0        0        1
#       vhigh        1        0        0            0        0        1
#       vhigh        1        0        0            0        0        1
#       vhigh        1        0        0            0        0        1
#       vhigh        1        0        0            0        0        0
#       vhigh        1        0        0            0        0        0
#       vhigh        1        0        0            0        0        0
#       vhigh        1        0        0            0        0        0
#       vhigh        1        0        0            0        0        0
#       vhigh        1        0        0            0        0        0
#       vhigh        1        0        0            0        0        0
#       vhigh        1        0        0            0        0        0
#       vhigh        1        0        0            0        0        0
#       vhigh        0        1        0            0        1        0
#       vhigh        0        1        0            0        1        0
#       vhigh        0        1        0            0        1        0
# ...              ...      ...      ...          ...      ...      ...
# low   low          0        0        1            0        0        0
#       low                0             1             0
#       low                0             0             1
#       low                1             0             0
#       low                0             1             0
#       low                0             0             1
#       low                1             0             0
#       low                0             1             0
#       low                0             0             1
#       low                1             0             0
#       low                0             1             0
#       low                0             0             1
#       low                1             0             0
#       low                0             1             0
#       low                0             0             1
#       low                1             0             0
#       low                0             1             0
#       low                0             0             1
#       low                1             0             0
#       low                0             1             0
#       low                0             0             1
#       low                1             0             0
#       low                0             1             0
#       low                0             0             1
#       low                1             0             0
#       low                0             1             0
#       low                0             0             1
#       low                1             0             0
#
# [1728 rows x 13 columns]

# %%
y = pd.get_dummies(y)

# %%
y
# Out:
#              acc  good  unacc  vgood
# vhigh vhigh    0     0      1      0
#       vhigh    0     0      1      0
#       vhigh    0     0      1      0
#       vhigh    0     0      1      0
#       vhigh    0     0      1      0
#       vhigh    0     0      1      0
#       vhigh    0     0      1      0
#       vhigh    0     0      1      0
#       vhigh    0     0      1      0
#       vhigh    0     0      1      0
#       vhigh    0     0      1      0
#       vhigh    0     0      1      0
#       vhigh    0     0      1      0
#       vhigh    0     0      1      0
#       vhigh    0     0      1      0
#       vhigh    0     0      1      0
#       vhigh    0     0      1      0
#       vhigh    0     0      1      0
#       vhigh    0     0      1      0
#       vhigh    0     0      1      0
#       vhigh    0     0      1      0
#       vhigh    0     0      1      0
#       vhigh    0     0      1      0
#       vhigh    0     0      1      0
#       vhigh    0     0      1      0
#       vhigh    0     0      1      0
#       vhigh    0     0      1      0
#       vhigh    0     0      1      0
#       vhigh    0     0      1      0
#       vhigh    0     0      1      0
# ...          ...   ...    ...    ...
# low   low      0     0      1      0
#       low      0     1      0      0
#       low      0     0      0      1
#       low      0     0      1      0
#       low      0     0      1      0
#       low      0     0      1      0
#       low      0     0      1      0
#       low      0     0      1      0
#       low      0     0      1      0
#       low      0     0      1      0
#       low      0     0      1      0
#       low      0     0      1      0
#       low      0     0      1      0
#       low      1     0      0      0
#       low      0     1      0      0
#       low      0     0      1      0
#       low      0     1      0      0
#       low      0     0      0      1
#       low      0     0      1      0
#       low      0     1      0      0
#       low      0     0      0      1
#       low      0     0      1      0
#       low      1     0      0      0
#       low      0     1      0      0
#       low      0     0      1      0
#       low      0     1      0      0
#       low      0     0      0      1
#       low      0     0      1      0
#       low      0     1      0      0
#       low      0     0      0      1
#
# [1728 rows x 4 columns]

# %%
from sklearn.neural_network import MLPRegressor

# %%
model=MLPRegressor(hidden_layer_sizes=(100,100,20),max_iter=6000000)

# %%
model.fit(x,y)
# Out:
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100, 100, 20), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=6000000, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)

# %%
model.score(x,y)
# Out:
# 0.4869270421685224

# %%
model.predict(x)
# Out:
# array([[ 0.0265953 ,  0.02602603,  0.97532445,  0.06619043],
#        [-0.00549148,  0.00409565,  1.02336189,  0.01985527],
#        [ 0.02215449,  0.04102808,  0.99937146, -0.04019836],
#        ...,
#        [ 0.0428429 ,  0.00492726,  0.98282662,  0.03603362],
#        [ 0.65794857,  0.20995526,  0.16097336,  0.03300061],
#        [ 0.50964949, -0.00381086,  0.1531298 ,  0.26669534]])

# %%
plt.plot(model.predict(x), 'ob')
plt.plot(y,'ob')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-d877447d1ed8> in <module>()
#       1 plt.plot(model.predict(x), 'ob')
# ----> 2 plt.plot(y,'ob')
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(*args, **kwargs)
#    3361                       mplDeprecation)
#    3362     try:
# -> 3363         ret = ax.plot(*args, **kwargs)
#    3364     finally:
#    3365         ax._hold = washold
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1865                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1866                         RuntimeWarning, stacklevel=2)
# -> 1867             return func(ax, *args, **kwargs)
#    1868
#    1869         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, *args, **kwargs)
#    1526         kwargs = cbook.normalize_kwargs(kwargs, _alias_map)
#    1527
# -> 1528         for line in self._get_lines(*args, **kwargs):
#    1529             self.add_line(line)
#    1530             lines.append(line)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _grab_next_args(self, *args, **kwargs)
#     404                 this += args[0],
#     405                 args = args[1:]
# --> 406             for seg in self._plot_args(this, kwargs):
#     407                 yield seg
#     408
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     381             x, y = index_of(tup[-1])
#     382
# --> 383         x, y = self._xy_from_xy(x, y)
#     384
#     385         if self.command == 'plot':
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _xy_from_xy(self, x, y)
#     213     def _xy_from_xy(self, x, y):
#     214         if self.axes.xaxis is not None and self.axes.yaxis is not None:
# --> 215             bx = self.axes.xaxis.update_units(x)
#     216             by = self.axes.yaxis.update_units(y)
#     217
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in update_units(self, data)
#    1467         neednew = self.converter != converter
#    1468         self.converter = converter
# -> 1469         default = self.converter.default_units(data, self)
#    1470         if default is not None and self.units is None:
#    1471             self.set_units(default)
#
# ~\Anaconda3\lib\site-packages\matplotlib\category.py in default_units(data, axis)
#     113         # default_units->axis_info->convert
#     114         if axis.units is None:
# --> 115             axis.set_units(UnitData(data))
#     116         else:
#     117             axis.units.update(data)
#
# ~\Anaconda3\lib\site-packages\matplotlib\category.py in __init__(self, data)
#     180         self._counter = itertools.count(start=0)
#     181         if data is not None:
# --> 182             self.update(data)
#     183
#     184     def update(self, data):
#
# ~\Anaconda3\lib\site-packages\matplotlib\category.py in update(self, data)
#     199         for val in OrderedDict.fromkeys(data):
#     200             if not isinstance(val, VALID_TYPES):
# --> 201                 raise TypeError("{val!r} is not a string".format(val=val))
#     202             if val not in self._mapping:
#     203                 self._mapping[val] = next(self._counter)
#
# TypeError: ('vhigh', 'vhigh') is not a string
